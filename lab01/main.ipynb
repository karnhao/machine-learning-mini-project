# %% [markdown]
# ### Import Libraries

# %%
# %pip install openpyxl
# Out:
# ...
#
# ...
#      ---------------------------------------- 0.0/250.0 kB ? eta -:--:--
#      - -------------------------------------- 10.2/250.0 kB ? eta -:--:--
#      ---- -------------------------------- 30.7/250.0 kB 435.7 kB/s eta 0:00:01
#      ------ ------------------------------ 41.0/250.0 kB 393.8 kB/s eta 0:00:01
#      ------------- ----------------------- 92.2/250.0 kB 655.4 kB/s eta 0:00:01
#      -------------------------------------  245.8/250.0 kB 1.5 MB/s eta 0:00:01
#      -------------------------------------- 250.0/250.0 kB 1.5 MB/s eta 0:00:00
# ...
# [notice] A new release of pip is available: 23.2.1 -> 23.3.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_excel("complaints.xlsx")
data
# Out:
#       เลขรับ กปม.     เลขหนังสือ ลงวันที่\n(คีย์เป็นเลข)  \
# 0           812.0   สผ 0001/6925              2021-05-31
# 1             NaN   สผ 0001/9215              2020-09-21
# 2           558.0   สผ 0001/2468              2022-03-01
# 3          2174.0  สผ 0025/11287              2022-09-23
# 4             NaN    สว 0001/377              2021-01-29
# ...           ...            ...                     ...
# 2151       1508.0   สผ 0001/7115              2022-06-27
# 2152        149.0    สผ 0001/257              2022-01-18
# 2153          NaN   สผ 0001/9215              2020-09-21
# 2154          NaN   สผ 0001/9221              2020-09-21
# 2155          NaN    สว 0001/377              2021-01-29
#
#      วันที่รับเรื่อง\n(คีย์เป็นเลข)  ปีที่  สมัยสามัญ\nครั้งที่  ครั้งที่  \
# 0                        2021-06-21    NaN                  NaN       NaN
# 1                        2020-09-24    2.0                  1.0      18.0
# ...

# %%
data.columns
# Out:
# Index(['เลขรับ กปม.', 'เลขหนังสือ', 'ลงวันที่\n(คีย์เป็นเลข)',
#        'วันที่รับเรื่อง\n(คีย์เป็นเลข)', 'ปีที่', 'สมัยสามัญ\nครั้งที่',
#        'ครั้งที่', 'วันที่ประชุม / เรื่องร้องเรียนมา (คีย์เป็นเลข)', 'ประเภท',
#        'ประเภทบุคคล (Auto)', 'พรรคการเมือง', 'ส.ส. เขต / บัญชีรายชื่อ\n(Auto)',
#        'ประเด็นที่ร้องเรียน', 'หมวดหมู่ปัญหา (เลือก)', 'พื้นที่ / ภูมิภาค',
#        'จำนวนส่ง\n(Auto)', 'ข้อพิจารณา\n(เลือก)', 'หน่วยงาน\nที่เกี่ยวข้อง',
#        'รอง นรม. / รมต.นร. ที่กำกับการดำเนินการ',
#        'วันที่แจ้งบัญชา\n(คีย์เป็นเลข)', 'เลขหนังสือ\nแจ้งหน่วยงาน',
#        'Deadline ติดตาม\n(Auto)', 'การติดตาม\n(Auto)', 'สถานะ\n(Auto)',
#        'การทวง', 'เลขที่หนังสือ\n/ลงวันที่', 'วันที่รับ\nหนังสือตอบกลับ',
#        'สถานะคำตอบ\n(เลือก)', 'เลขหนังสือ\nตอบสภาฯ', 'วิเคราะห์คำตอบ', 'คำตอบ',
#        'วันที่ปิดเรื่อง\n(ตอบสภา)\n(คีย์เป็นเลข)', 'Unnamed: 34', 'หมายเหตุ',
#        'การ Update'],
#       dtype='object')

# %%
data = data[["ประเด็นที่ร้องเรียน", "หมวดหมู่ปัญหา (เลือก)", "พื้นที่ / ภูมิภาค", "หน่วยงาน\nที่เกี่ยวข้อง"]]
data
# Out:
#                                     ประเด็นที่ร้องเรียน หมวดหมู่ปัญหา (เลือก)  \
# 0     ขอหน่วยงานที่เกี่ยวข้องวางท่อส่งน้ำสำหรับขยายเ...                   น้ำ
# 1     ขอให้หน่วยงานที่เกี่ยวข้องดำเนินการแก้ไขปัญหาร...                อื่น ๆ
# 2     ขอให้ช่วยเหลือเยียวยาประชาชนที่ได้รับผลกระทบจา...             สาธารณภัย
# 3     ๑. ขออนุญาตตั้งวัดพระพุทธบาทบัวบก ให้เป็นวัดที...  ศิลปะ วัฒนธรรม ศาสนา
# 4     ขอให้รัฐบาลทบทวนการแก้ไขปัญหาประชาคมกระเหรี่ยง...           ที่ดินทำกิน
# ...                                                 ...                   ...
# 2151  ขอให้พิจารณากำกับดูแลและเร่งดำเนินการจัดทำร่าง...              การเมือง
# 2152  ขอให้หน่วยงานที่เกี่ยวข้องบูรณาการการทำงานร่วม...             สวัสดิการ
# 2153  ขอให้หน่วยงานที่เกี่ยวข้องดำเนินการฟื้นฟูเศรษฐ...      เศรษฐกิจ การคลัง
# 2154  ขอความอนุเคราะห์ให้จัดระบบประปาหมู่บ้าน ม.6 บ้...                   น้ำ
# 2155  ขอให้รัฐบาลทบทวนการแก้ไขปัญหาประชาคมกระเหรี่ยง...           ที่ดินทำกิน
#
# ...

# %%
data.dropna(inplace=True)
data
# Out:
# C:\Users\PC306\AppData\Local\Temp\ipykernel_5716\731352529.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data.dropna(inplace=True)
#                                     ประเด็นที่ร้องเรียน  \
# 0     ขอหน่วยงานที่เกี่ยวข้องวางท่อส่งน้ำสำหรับขยายเ...
# 1     ขอให้หน่วยงานที่เกี่ยวข้องดำเนินการแก้ไขปัญหาร...
# 2     ขอให้ช่วยเหลือเยียวยาประชาชนที่ได้รับผลกระทบจา...
# 4     ขอให้รัฐบาลทบทวนการแก้ไขปัญหาประชาคมกระเหรี่ยง...
# 5     ขอให้พิจารณาดำเนินการแก้ไขปัญหาการลักลอบเล่นพน...
# ...                                                 ...
# 2151  ขอให้พิจารณากำกับดูแลและเร่งดำเนินการจัดทำร่าง...
# 2152  ขอให้หน่วยงานที่เกี่ยวข้องบูรณาการการทำงานร่วม...
# 2153  ขอให้หน่วยงานที่เกี่ยวข้องดำเนินการฟื้นฟูเศรษฐ...
# 2154  ขอความอนุเคราะห์ให้จัดระบบประปาหมู่บ้าน ม.6 บ้...
# ...

# %%
print(data["หมวดหมู่ปัญหา (เลือก)"].unique())
print(data["หมวดหมู่ปัญหา (เลือก)"].unique().size)
data["หมวดหมู่ปัญหา (เลือก)"].value_counts("")
# Out:
# ['น้ำ' 'อื่น ๆ' 'สาธารณภัย' 'ที่ดินทำกิน' 'อาชญากรรม ยาเสพติดและการพนัน'
#  'สาธารณสุข' 'หนี้สิน เศรษฐกิจฐานราก' 'การบริหารราชการแผ่นดิน' 'การเกษตร'
#  'ราคาสินค้าเกษตร' 'ศิลปะ วัฒนธรรม ศาสนา' 'อุตสาหกรรม'
#  'การคมนาคม การจราจรหรืออุบัติเหตุ' 'โครงสร้างพื้นฐานและสาธารณูปโภค'
#  'การศึกษา' 'ผู้มีอิทธิพล การทุจริตและประพฤติมิชอบ' 'เศรษฐกิจ การคลัง'
#  'กฎหมายและกระบวนการยุติธรรม' 'การต่างประเทศ' 'โทรคมนาคมและการสื่อสาร'
#  'การท่องเที่ยว' 'สวัสดิการ' 'การเมือง' 'เทคโนโลยีและดิจิทัล' 'พลังงาน'
#  'แรงงาน' 'สิ่งแวดล้อม' 'การพาณิชย์' 'โรคระบาดพืชและสัตว์' 'ความมั่นคง'
#  'วิจัย วิทยาศาสตร์ และนวัตกรรม' 'การกีฬา' 'ประมง' 'ความหลากหลายทางสังคม']
# 34
# หมวดหมู่ปัญหา (เลือก)
# สาธารณสุข                                194
# โครงสร้างพื้นฐานและสาธารณูปโภค           149
# การบริหารราชการแผ่นดิน                   133
# อาชญากรรม ยาเสพติดและการพนัน             129
# น้ำ                                      128
# ที่ดินทำกิน                              122
# ...

# %%
a = data["หมวดหมู่ปัญหา (เลือก)"].astype("category")
a = a.cat.codes
a
# Out:
# 0       13
# 1       26
# 2       21
# 4       12
# 5       25
#         ..
# 2151     9
# 2152    20
# 2153    29
# 2154    13
# 2155    12
# Length: 1957, dtype: int8

# %%
print(data["พื้นที่ / ภูมิภาค"].unique())
print(data["พื้นที่ / ภูมิภาค"].unique().size)
data["พื้นที่ / ภูมิภาค"].value_counts()
# Out:
# ['สระบุรี' 'ทุกภูมิภาค' 'สุพรรณบุรี' 'เพชรบุรี' 'กรุงเทพมหานคร' 'จันทบุรี'
#  'น่าน' 'ประจวบคีรีขันธ์' 'ลำพูน' 'ระยอง' 'เชียงใหม่' 'มุกดาหาร' 'ตาก'
#  'ขอนแก่น' 'พัทลุง' 'ชัยภูมิ' 'นครราชสีมา' 'ภาคตะวันออก' 'อุบลราชธานี'
#  'มหาสารคาม' 'กาฬสินธุ์,ร้อยเอ็ด' 'นครศรีธรรมราช' 'นราธิวาส' 'ศรีสะเกษ'
#  'สมุทรปราการ' 'ภูเก็ต' 'สมุทรสงคราม' 'ปทุมธานี' 'ยะลา' 'ปทุมธานี/อยุธยา'
#  'พระนครศรีอยุธยา, ลพบุรี, สระบุรี' 'นนทบุรี'
#  'นครพนม, อุดรธานี, มหาสารคาม, มุกดาหาร, สกลนคร' 'พิษณุโลก'
#  'พระนครศรีอยุธยา' 'นครปฐม' 'สมุทรสาคร' 'เชียงราย' 'ชลบุรี' 'ตราด'
#  'สุราษฎร์ธานี' 'พัทลุง, สงขลา' 'นโยบายภาพรวม' 'เพชรบูรณ์' 'ราชบุรี'
#  'สงขลา' 'กระบี่' 'ลพบุรี' 'ปราจีนบุรี' 'กำแพงเพชร' 'สกลนคร' 'สุรินทร์'
#  'นราธิวาส, ปัตตานี, ยะลา, สงขลา' 'อุดรธานี'
#  'ยะลา, ปัตตานี, นราธิวาส, สงขลา' 'สระแก้ว' 'ฉะเชิงเทรา' 'ภาคเหนือ'
#  'บุรีรัมย์' 'ลำปาง' 'กาฬสินธุ์' 'ชุมพร'
#  'อุดรธานี, หนองคาย, หนองบัวลำภู, เลย, สกลนคร, นครพนม, มุกดาหาร, อำนาจเจริญ'
# ...

# %%
print(data["หน่วยงาน\nที่เกี่ยวข้อง"].unique())
print(data["หน่วยงาน\nที่เกี่ยวข้อง"].unique().size)
data["หน่วยงาน\nที่เกี่ยวข้อง"].value_counts()
# Out:
# ['สปน.' 'กต.' 'กษ.' 'ทส.' 'ตร.' 'มท.' 'สธ.' 'คค.' 'สลค.' 'กค.' 'ศบค.'
#  'ดศ.' 'ศธ.' 'ศบศ.' 'อก.' 'ยธ.' 'พศ.' 'กก.' 'ศปก. ศบค.' 'สทนช.' 'พม.'
#  'สงป.' 'พณ.' 'ผบ.ตร.' 'รง.'
#  'คกก. ตรวจสอบการกระทำความผิดกรณีสถานที่เล่นการพนัน' 'กอ.รมน.' 'ศคบ.'
#  'กทบ.' 'พน.' 'สคทช.' 'อว.' 'สคบ.' 'สลน.' 'สทบ.' 'สศช.'
#  'กก. ตรวจสอบการกระทำความผิดกรณีสถานที่เล่นการพนัน' 'สนล.' 'สนทช.' 'กห.'
#  'ปชส.' 'BOI' 'ศอ.บต.' 'สมช.' 'ป.ป.ท.' 'วธ.' 'ก.ก.ถ.' 'สคก.' 'ททท.' 'ก.พ.'
#  'ป.ป.ช.' 'รย.' 'สขช.'
#  'กมธ. วิสามัญพิจารณาศึกษาร่าง พ.ร.บ.งบประมาณรายจ่ายประจำปีงบประมาณ พ.ศ. ๒๕๖๖'
#  'อสส.' 'กกต.' 'สสว.' 'กสทช.'
#  'คณะอนุกรรมการ\nบูรณาการนโยบายพัฒนาภาคใต้และ\nภาคใต้ชายแดน' 'ศรชล.'
#  'ก.พ.ร.' 'สกพอ.' 'คบศ.' 'สนข.' 'นรม.' 'ครม.' 'คกก.' 'สกถ.' 'ศย.' 'ป.ป.ง.'
#  'คกก. ปฏิรูปฯ' 'เลย']
# 72
# หน่วยงาน\nที่เกี่ยวข้อง
# มท.                                                  343
# ตร.                                                  196
# สปน.                                                 176
# ...

# %%
data.to_csv("./data.csv", encoding="utf-8-sig")
